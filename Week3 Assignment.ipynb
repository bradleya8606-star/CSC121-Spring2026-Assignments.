# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/Week3%20Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, brith_year, current_year
name = "Aiden Bradley"
goal = "I want to be a game developer."
birth_year = 2006
current_year = 2026
# Caculate age
age = current_year - birth_year
# Print top border
print("=" * 100)
# Print bio sentance
print("My name is " + name + " and I am " + str(age) + " years old." + "And it is my goal is that " + goal)
# Print bottom border
print("=" * 100)
# Out:
# ====================================================================================================
# My name is Aiden Bradley and I am 20 years old.And it is my goal is that I want to be a game developer.
# ====================================================================================================
