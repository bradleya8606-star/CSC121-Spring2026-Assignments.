# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, brith_year, current_year
name = "Name: Aiden Bradley :"
age = ":20"
goal = " Goal: Learn Python"
birth_year = 2006
current_year = 2026
# Caculate age
age = current_year - birth_year
# Print top border
print("=" * 35)
# Print bio sentance
print(name + str(age) + goal)
# Print bottom border
print("=" * 35)

Name = "Name: Hanna Montana "
Age = ":33 "
Goal = "Goal: Become a Python Developer"

# Print top border
print("=" * 35)
# Print bio sentance
print(Name + str(Age) + Goal)
# Print bottom border
print("=" * 35)


name_3 = "Name: Dumbledor "
age_3 = ":52 "
goal_3 = "Goal: to help others in need"
# Print top border
print("=" * 35)
# Print bio sentance
print(name_3 + str(age_3) + goal_3)
# Print bottom border
print("=" * 35)
# Out:
# ...
# Name: Aiden Bradley :20 Goal: Learn Python
# ...
# Name: Hanna Montana :33 Goal: Become a Python Developer
# ...
# Name: Dumbledor :52 Goal: to help others in need
# ...
