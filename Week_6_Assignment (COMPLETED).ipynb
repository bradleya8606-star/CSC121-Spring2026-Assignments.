# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/Week_6_Assignment%20(COMPLETED).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
import math
radius = 4
height = 7
# FUNCTION DEFINITIONS
def area(radius):
    return math.pi * radius ** 2

def circumference(radius):
    return 2 * math.pi * radius

def volume(radius, height):
    # Fruitful approach: reuse area function
    return area(radius) * height

# PROGRAM LOGIC
radius = float(input("Enter the radius: "))

print("Area:", area(radius))
print("Circumference:", circumference(radius))

height = float(input("Enter the height: "))

print("Volume:", volume(radius, height))
# Out:
# Enter the radius: 4
# Area: 50.26548245743669
# Circumference: 25.132741228718345
# Enter the height: 7
# Volume: 351.85837720205683
