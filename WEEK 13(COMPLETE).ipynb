# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/WEEK%2013(COMPLETE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py


# NAME: journal.py

# IMPORT STATEMENTS
import datetime

# FUNCTION DEFINITIONS
def write_entry(entry_text, filename="journal.txt"):
    """



# IMPORT STATEMENTS
import datetime

# FUNCTION DEFINITIONS
def write_entry(entry_text, filename="journal.txt"):
    """
    Appends a journal entry to the specified file, prefixed with a timestamp.
    """
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(filename, "a") as file:
        file.write(f"{timestamp} - {entry_text}\n")
    print("Entry saved.\n")

# PROGRAM LOGIC
def main():
    print("Welcome to your journal!")
    while True:
        entry = input("Write your journal entry (or type 'quit' to exit): ")
        if entry.lower() == "quit":
            print("Goodbye!")
            break
        write_entry(entry)

if __name__ == "__main__":
    main()
# Out:
# Welcome to your journal!
# Write your journal entry (or type 'quit' to exit): This is a test to see if the code works as intended :)
# Entry saved.
#
# Write your journal entry (or type 'quit' to exit): quit
# Goodbye!
