# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/Chapter_7_assignment(COMPLETE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS

# 1. Define verify_pin()
def verify_pin():
    while True:
        pin = input("Enter your PIN: ")
        if pin == "1234":
            print("PIN accepted.")
            return True
        else:
            print("Incorrect PIN. Try again.")

# 2. Define withdraw(balance, amount)
def withdraw(balance, amount):
    if amount <= balance:
        balance -= amount
        print("Withdrawal successful.")
    else:
        print("Insufficient funds. Withdrawal canceled.")
    return balance


# PROGRAM LOGIC

# 1. Set current_balance to 500
current_balance = 500

# 2. Call verify_pin()
verify_pin()

# 3. Get withdrawal amount from user input
amount = float(input("Enter amount to withdraw: "))

# 4. Update current_balance by calling withdraw()
current_balance = withdraw(current_balance, amount)

# 5. Print the final balance
print("Final balance:", current_balance)
# Out:
# Enter your PIN: 1234
# PIN accepted.
# Enter amount to withdraw: 33
# Withdrawal successful.
# Final balance: 467.0
