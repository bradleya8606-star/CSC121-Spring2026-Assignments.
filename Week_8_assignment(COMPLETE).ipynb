# %% [markdown]
# <a href="https://colab.research.google.com/github/bradleya8606-star/CSC121-Spring2026-Assignments./blob/main/Week_8_assignment(COMPLETE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None needed for this function)

# FUNCTION DEFINITIONS
def is_palindrome(text):
    """
    Returns True if the given text is a palindrome,
    otherwise returns False.
    """
    # Normalize the text (remove spaces and make lowercase)
    cleaned_text = text.replace(" ", "").lower()

    # Compare the string to its reverse
    return cleaned_text == cleaned_text[::-1]


# PROGRAM LOGIC
# Get user input
user_input = input("Enter a word or phrase: ")

# Check if it is a palindrome
if is_palindrome(user_input):
    print(f'"{user_input}" is a palindrome.')
else:
    print(f'"{user_input}" is NOT a palindrome.')


# Manual verification tests
print("\nManual Tests:")
print("Racecar:", is_palindrome("Racecar"))  # Expected: True
print("racecar:", is_palindrome("racecar"))  # Expected: True
# Out:
# Enter a word or phrase: racecar
# "racecar" is a palindrome.
#
# Manual Tests:
# Racecar: True
# racecar: True
